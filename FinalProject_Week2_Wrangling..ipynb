# %%
import pandas as pd

# %%
Saleries = pd.read_csv(r'C:\Users\lien0\OneDrive\Documents\Data Science Salaries _cleaned 2021.csv')
Saleries.head()
# Out:
#    index                  Job Title              Salary Estimate  \
# 0      0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1      1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2      2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3      3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4      4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
Saleries.drop(['Salary Estimate', 'Job Description', 'Headquarters', 'Size', 'Founded', 'Revenue', 'Competitors', 'Hourly', 'Employer provided', 'company_txt', 'Age', 'job_title_sim', 'seniority_by_title'], axis= 1, inplace= True)

# %%
Saleries.head()
# Out:
#    index                  Job Title  Rating  \
# 0      0             Data Scientist     3.8
# 1      1  Healthcare Data Scientist     3.4
# 2      2             Data Scientist     4.8
# 3      3             Data Scientist     3.8
# 4      4             Data Scientist     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
#     Type of ownership                          Industry  \
# 0   Company - Private               Aerospace & Defense
# 1  Other Organization  Health Care Services & Hospitals
# 2   Company - Private                 Security Services
# 3          Government                            Energy
# ...

# %%
Saleries['Company Name'].value_counts()
# Out:
# MassMutual\n3.6                                         14
# Reynolds American\n3.1                                  14
# Takeda Pharmaceuticals\n3.7                             14
# Software Engineering Institute\n2.6                     11
# PNNL\n3.8                                               10
#                                                         ..
# Dayton Freight Lines, Inc.\n4.3                          1
# Community Action Partnership of San Luis Obispo\n2.8     1
# TrueAccord\n3.4                                          1
# DRB Systems\n4.0                                         1
# Fivestars\n3.9                                           1
# Name: Company Name, Length: 343, dtype: int64

# %%
Saleries['Sector'].value_counts()
# Out:
# Information Technology                180
# Biotech & Pharmaceuticals             112
# Business Services                      97
# Insurance                              69
# Health Care                            49
# Finance                                42
# Manufacturing                          34
# Aerospace & Defense                    25
# Education                              23
# Retail                                 15
# Oil, Gas, Energy & Utilities           14
# Government                             11
# -1                                     10
# Non-Profit                              9
# Transportation & Logistics              8
# Real Estate                             8
# Travel & Tourism                        8
# Telecommunications                      6
# Media                                   6
# Arts, Entertainment & Recreation        4
# Consumer Services                       4
# Mining & Metals                         3
# ...

# %%
Saleries["Type of ownership"].value_counts()
# Out:
# Company - Private                 410
# Company - Public                  193
# Nonprofit Organization             55
# Subsidiary or Business Segment     34
# Government                         15
# Hospital                           15
# College / University               13
# Other Organization                  5
# School / School District            2
# Name: Type of ownership, dtype: int64

# %%
Saleries[['City', 'State']] = Saleries['Location'].str.split(',', 1, expand=True)

# %%
Saleries.head()
# Out:
#    index                  Job Title  Rating  \
# 0      0             Data Scientist     3.8
# 1      1  Healthcare Data Scientist     3.4
# 2      2             Data Scientist     4.8
# 3      3             Data Scientist     3.8
# 4      4             Data Scientist     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
#     Type of ownership                          Industry  \
# 0   Company - Private               Aerospace & Defense
# 1  Other Organization  Health Care Services & Hospitals
# 2   Company - Private                 Security Services
# 3          Government                            Energy
# ...

# %%
state_count = Saleries["State"].value_counts().loc[lambda y : y>9]
state_count
# Out:
#  CA    151
#  MA    103
#  NY     72
#  VA     41
#  IL     40
#  MD     35
#  PA     33
#  TX     28
#  WA     21
#  NC     21
#  NJ     17
#  FL     16
#  OH     14
#  TN     13
#  DC     11
#  CO     11
#  WI     10
#  IN     10
#  UT     10
# Name: State, dtype: int64

# %%
Saleries.join(pd.)
# Out:
#    index                  Job Title  Rating  \
# 0      0             Data Scientist     3.8
# 1      1  Healthcare Data Scientist     3.4
# 2      2             Data Scientist     4.8
# 3      3             Data Scientist     3.8
# 4      4             Data Scientist     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
#     Type of ownership                          Industry  \
# 0   Company - Private               Aerospace & Defense
# 1  Other Organization  Health Care Services & Hospitals
# 2   Company - Private                 Security Services
# 3          Government                            Energy
# ...

# %%
Saleries.drop('State_count', axis=1)
Saleries.head()
# Out:
#    index                  Job Title  Rating  \
# 0      0             Data Scientist     3.8
# 1      1  Healthcare Data Scientist     3.4
# 2      2             Data Scientist     4.8
# 3      3             Data Scientist     3.8
# 4      4             Data Scientist     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
#     Type of ownership                          Industry  \
# 0   Company - Private               Aerospace & Defense
# 1  Other Organization  Health Care Services & Hospitals
# 2   Company - Private                 Security Services
# 3          Government                            Energy
# ...

# %%
del Saleries['State_count']
Saleries.head()
# Out:
#    index                  Job Title  Rating  \
# 0      0             Data Scientist     3.8
# 1      1  Healthcare Data Scientist     3.4
# 2      2             Data Scientist     4.8
# 3      3             Data Scientist     3.8
# 4      4             Data Scientist     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
#     Type of ownership                          Industry  \
# 0   Company - Private               Aerospace & Defense
# 1  Other Organization  Health Care Services & Hospitals
# 2   Company - Private                 Security Services
# 3          Government                            Energy
# ...
